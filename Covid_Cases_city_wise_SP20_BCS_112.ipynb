# %%
#import libraries
import folium
import pandas as pd

# %%
#create a map on Pakistan location
pakistan_map = folium.Map(location = [30.37,69.34],zoom_start=4.5,tiles='OpenStreetMap')

# %%
#import Google Drive and mount the entire drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load the dataset (csv file) into the Pandas dataframe
df = pd.read_csv('/content/drive/My Drive/IDS/CitiesLongLati.csv')

# %%
#calculate total number of cases using a loop
t = 0
for c in df['Total cases']:
  t = int(c)+int(t)

# %%
#mark circles on the map and displa the map
for District,lat,long,tc,ac,de,re in zip(list(df['District']),list(df['Latitudes']),list(df['Longitudes']),list(df['Total cases']),list(df['Active cases']),list(df['Deaths']),list(df['Recoveries'])):
    folium.CircleMarker(location = [lat,long],
                       radius = (tc/t)*100,
                       color = 'red',
                       fill = False,
                       fill_color = 'blue').add_to(pakistan_map)
    xyz = '<strong>District:  ' + District +'</strong><br>' + 'Total Cases: ' + str(tc)+'<br>' + 'Active cases: ' + str(ac)+ '<br>' + 'Deaths: ' + str(de)+ '<br>' + 'Recoveries: ' + str(re)
    iframe = folium.IFrame(xyz, width=200, height=150)
    popupData = folium.Popup(iframe, max_width=500)
    folium.Marker(location = [lat,long], popup=popupData).add_to(pakistan_map)
    

pakistan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e65b701e27eebbeaba81c283a3bb2584 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e65b701e27eebbeaba81c283a3bb2584&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e65b701e27eebbeaba81c283a3bb2584 = L.map(
#                 &quot;map_e65b701e27eebbeaba81c283a3bb2584&quot;,
#                 {
#                     center: [30.37, 69.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6bdba32ff617e280f900a24197046c5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e65b701e27eebbeaba81c283a3bb2584);
#
#
#             var circle_marker_d00f1975734e885f6d1ae3ed54bf7042 = L.circleMarker(
#                 [31.558, 74.35071],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 54.02206389335785, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e65b701e27eebbeaba81c283a3bb2584);
#
#
#             var marker_661258d2ef0418d069af1d521b685b3a = L.marker(
#                 [31.558, 74.35071],
#                 {}
#             ).addTo(map_e65b701e27eebbeaba81c283a3bb2584);
#
#
#         var popup_413c43c28b7f20db443c1711d352907c = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_66f6b6732ec1405cae04637071022d15 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPjxicj5Ub3RhbCBDYXNlczogNDcwMTxcc3Ryb25nPjxicj5BY3RpdmUgY2FzZXM6IDIwNzc8XHN0cm9uZz48YnI+RGVhdGhzOiAzNTI8XHN0cm9uZz48YnI+UmVjb3ZlcmllczogMjI3Mg==&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_413c43c28b7f20db443c1711d352907c.setContent(i_frame_66f6b6732ec1405cae04637071022d15);
#
#
#         marker_661258d2ef0418d069af1d521b685b3a.bindPopup(popup_413c43c28b7f20db443c1711d352907c)
#         ;
#
#
#
#
#             var circle_marker_aece7d5d8caf2abc0b361bca2bdfc647 = L.circleMarker(
#                 [32.9425, 73.7257],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.689496667432774, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e65b701e27eebbeaba81c283a3bb2584);
#
#
#             var marker_1b3fc4cf1b05680233c3fcfe9c24b494 = L.marker(
#                 [32.9425, 73.7257],
#                 {}
#             ).addTo(map_e65b701e27eebbeaba81c283a3bb2584);
#
#
#         var popup_9f7cb1e750b8aa6eeeefddd0c95238f9 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_7871be76b395ea2799de8d3734b1bd16 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPjxicj5Ub3RhbCBDYXNlczogNjA8XHN0cm9uZz48YnI+QWN0aXZlIGNhc2VzOiAzMDxcc3Ryb25nPjxicj5EZWF0aHM6IDEyPFxzdHJvbmc+PGJyPlJlY292ZXJpZXM6IDE4&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_9f7cb1e750b8aa6eeeefddd0c95238f9.setContent(i_frame_7871be76b395ea2799de8d3734b1bd16);
#
#
#         marker_1b3fc4cf1b05680233c3fcfe9c24b494.bindPopup(popup_9f7cb1e750b8aa6eeeefddd0c95238f9)
#         ;
#
#
#
#
#             var circle_marker_145b8490ccf3cfceb6b635a60c6e5c9d = L.circleMarker(
#                 [33.5651, 73.0169],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.273500344748333, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e65b701e27eebbeaba81c283a3bb2584);
#
#
#             var marker_6178fffadd6f5cef9721b74da088ce25 = L.marker(
#                 [33.5651, 73.0169],
#                 {}
#             ).addTo(map_e65b701e27eebbeaba81c283a3bb2584);
#
#
#         var popup_7097a9010325e979646a23658ac67578 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_864d2a949830c37b53d5e
